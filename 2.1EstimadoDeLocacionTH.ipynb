# %%
import pandas as pd

# %%
df = pd.read_csv('../content/drive/MyDrive/DataSets2-TCH/Remoto Datasets/Remoto melbourne_housing-clean.csv', index_col=1)

# %%
df
# Out:
#               Unnamed: 0               address  rooms type      price method  \
# suburb
# Abbotsford             0          85 Turner St      2    h  1480000.0      S
# Abbotsford             1       25 Bloomburg St      2    h  1035000.0      S
# Abbotsford             2          5 Charles St      3    h  1465000.0     SP
# Abbotsford             3      40 Federation La      3    h   850000.0     PI
# Abbotsford             4           55a Park St      4    h  1600000.0     VB
# ...                  ...                   ...    ...  ...        ...    ...
# Whittlesea         11641         30 Sherwin St      3    h   601000.0      S
# Williamstown       11642           87 Pasco St      3    h  1285000.0      S
# Yarraville         11643           2 Adeney St      2    h   750000.0     SP
# Yarraville         11644       54 Pentland Pde      6    h  2450000.0     VB
# Yarraville         11645  10/127 Somerville Rd      3    t   645000.0     SP
#
#                    seller_g        date  distance  postcode  bedroom_2  \
# suburb
# Abbotsford           Biggin   3/12/2016       2.5    3067.0        2.0
# Abbotsford           Biggin   4/02/2016       2.5    3067.0        2.0
# Abbotsford           Biggin   4/03/2017       2.5    3067.0        3.0
# Abbotsford           Biggin   4/03/2017       2.5    3067.0        3.0
# Abbotsford           Nelson   4/06/2016       2.5    3067.0        3.0
# ...                     ...         ...       ...       ...        ...
# Whittlesea              Ray  29/07/2017      35.5    3757.0        3.0
# Williamstown            Jas  29/07/2017       6.8    3016.0        2.0
# Yarraville    hockingstuart  29/07/2017       6.3    3013.0        3.0
# Yarraville          Village  29/07/2017       6.3    3013.0        3.0
# Yarraville              Jas  29/07/2017       6.3    3013.0        2.0
#
#               bathroom  car  land_size council_area  latitude  longitude  \
# suburb
# Abbotsford         1.0  1.0      202.0        Yarra -37.79960  144.99840
# Abbotsford         1.0  0.0      156.0        Yarra -37.80790  144.99340
# Abbotsford         2.0  0.0      134.0        Yarra -37.80930  144.99440
# Abbotsford         2.0  1.0       94.0        Yarra -37.79690  144.99690
# Abbotsford         1.0  2.0      120.0        Yarra -37.80720  144.99410
# ...                ...  ...        ...          ...       ...        ...
# Whittlesea         2.0  2.0     1970.0   Manningham -37.76311  145.10494
# Williamstown       1.0  1.0     2010.0   Whittlesea -37.68199  145.01744
# Yarraville         2.0  2.0     1999.0      Darebin -37.75948  144.99615
# Yarraville         2.0  1.0     2011.0         Hume -37.70322  144.88236
# Yarraville         1.0  1.0     1980.0         Hume -37.69815  144.88019
#
#                         region_name  property_count
# suburb
# Abbotsford    Northern Metropolitan          4019.0
# Abbotsford    Northern Metropolitan          4019.0
# Abbotsford    Northern Metropolitan          4019.0
# Abbotsford    Northern Metropolitan          4019.0
# Abbotsford    Northern Metropolitan          4019.0
# ...                             ...             ...
# Whittlesea        Northern Victoria          2170.0
# Williamstown   Western Metropolitan          6380.0
# Yarraville     Western Metropolitan          6543.0
# Yarraville     Western Metropolitan          6543.0
# Yarraville     Western Metropolitan          6543.0
#
# [11646 rows x 19 columns]

# %%
df.head()
# Out:
#             Unnamed: 0           address  rooms type      price method  \
# suburb
# Abbotsford           0      85 Turner St      2    h  1480000.0      S
# Abbotsford           1   25 Bloomburg St      2    h  1035000.0      S
# Abbotsford           2      5 Charles St      3    h  1465000.0     SP
# Abbotsford           3  40 Federation La      3    h   850000.0     PI
# Abbotsford           4       55a Park St      4    h  1600000.0     VB
#
#            seller_g       date  distance  postcode  bedroom_2  bathroom  car  \
# suburb
# Abbotsford   Biggin  3/12/2016       2.5    3067.0        2.0       1.0  1.0
# Abbotsford   Biggin  4/02/2016       2.5    3067.0        2.0       1.0  0.0
# Abbotsford   Biggin  4/03/2017       2.5    3067.0        3.0       2.0  0.0
# Abbotsford   Biggin  4/03/2017       2.5    3067.0        3.0       2.0  1.0
# Abbotsford   Nelson  4/06/2016       2.5    3067.0        3.0       1.0  2.0
#
#             land_size council_area  latitude  longitude  \
# suburb
# Abbotsford      202.0        Yarra  -37.7996   144.9984
# Abbotsford      156.0        Yarra  -37.8079   144.9934
# Abbotsford      134.0        Yarra  -37.8093   144.9944
# Abbotsford       94.0        Yarra  -37.7969   144.9969
# Abbotsford      120.0        Yarra  -37.8072   144.9941
#
#                       region_name  property_count
# suburb
# Abbotsford  Northern Metropolitan          4019.0
# Abbotsford  Northern Metropolitan          4019.0
# Abbotsford  Northern Metropolitan          4019.0
# Abbotsford  Northern Metropolitan          4019.0
# Abbotsford  Northern Metropolitan          4019.0

# %% [markdown]
# **PROMEDIO**

# %% [markdown]
# Veamos cuál es el "valor típico" obtenido usando la media (promedio) de columna precio

# %%
df['price'].mean()
# Out:
# 1068141.895071269

# %% [markdown]
# **MEDIANA**

# %%
df['price'].median()
# Out:
# 895500.0

# %% [markdown]
# **MEDIANA TRUNCADA**: para cuando hay valores atípicos

# %%
from scipy import stats

# %%
stats.trim_mean(df['price'],0.1)
# Out:
# 973653.7960935823

# %%
df['price'].mean()
# Out:
# 1068141.895071269

# %%
df['price'].median()
# Out:
# 895500.0

# %% [markdown]
# **Desviación estándar**

# %%
df.head()
# Out:
#             Unnamed: 0           address  rooms type      price method  \
# suburb
# Abbotsford           0      85 Turner St      2    h  1480000.0      S
# Abbotsford           1   25 Bloomburg St      2    h  1035000.0      S
# Abbotsford           2      5 Charles St      3    h  1465000.0     SP
# Abbotsford           3  40 Federation La      3    h   850000.0     PI
# Abbotsford           4       55a Park St      4    h  1600000.0     VB
#
#            seller_g       date  distance  postcode  bedroom_2  bathroom  car  \
# suburb
# Abbotsford   Biggin  3/12/2016       2.5    3067.0        2.0       1.0  1.0
# Abbotsford   Biggin  4/02/2016       2.5    3067.0        2.0       1.0  0.0
# Abbotsford   Biggin  4/03/2017       2.5    3067.0        3.0       2.0  0.0
# Abbotsford   Biggin  4/03/2017       2.5    3067.0        3.0       2.0  1.0
# Abbotsford   Nelson  4/06/2016       2.5    3067.0        3.0       1.0  2.0
#
#             land_size council_area  latitude  longitude  \
# suburb
# Abbotsford      202.0        Yarra  -37.7996   144.9984
# Abbotsford      156.0        Yarra  -37.8079   144.9934
# Abbotsford      134.0        Yarra  -37.8093   144.9944
# Abbotsford       94.0        Yarra  -37.7969   144.9969
# Abbotsford      120.0        Yarra  -37.8072   144.9941
#
#                       region_name  property_count
# suburb
# Abbotsford  Northern Metropolitan          4019.0
# Abbotsford  Northern Metropolitan          4019.0
# Abbotsford  Northern Metropolitan          4019.0
# Abbotsford  Northern Metropolitan          4019.0
# Abbotsford  Northern Metropolitan          4019.0

# %%
df['price'].std()
# Out:
# 643728.1914372843

# %% [markdown]
# Entre mayor sea nuestro resultado quiere decir que nuestros datos están más dispersos (es decir, hay muchos datos que se alejan de nuestro valor típico); entre menor sea el resultado quiere decir que nuestros datos están menos dispersos (es decir, están más cerca de nuestro valor típico).
#
# Obviamente hay que tomar en cuenta el rango de nuestros valores para determinar si nuestra desviación estándar es pequeña o grande. Por ejemplo, una desviación estándar de 10 es muy pequeña si nuestros valores tienen un rango de 1 000 000. En cambio, una desviación estándar de 10 es mucho mayor si nuestros valores tienen un rango de 40.

# %% [markdown]
# ### **Estadísticos de Orden**

# %% [markdown]
# Rango

# %%
df.head()
# Out:
#             Unnamed: 0           address  rooms type      price method  \
# suburb
# Abbotsford           0      85 Turner St      2    h  1480000.0      S
# Abbotsford           1   25 Bloomburg St      2    h  1035000.0      S
# Abbotsford           2      5 Charles St      3    h  1465000.0     SP
# Abbotsford           3  40 Federation La      3    h   850000.0     PI
# Abbotsford           4       55a Park St      4    h  1600000.0     VB
#
#            seller_g       date  distance  postcode  bedroom_2  bathroom  car  \
# suburb
# Abbotsford   Biggin  3/12/2016       2.5    3067.0        2.0       1.0  1.0
# Abbotsford   Biggin  4/02/2016       2.5    3067.0        2.0       1.0  0.0
# Abbotsford   Biggin  4/03/2017       2.5    3067.0        3.0       2.0  0.0
# Abbotsford   Biggin  4/03/2017       2.5    3067.0        3.0       2.0  1.0
# Abbotsford   Nelson  4/06/2016       2.5    3067.0        3.0       1.0  2.0
#
#             land_size council_area  latitude  longitude  \
# suburb
# Abbotsford      202.0        Yarra  -37.7996   144.9984
# Abbotsford      156.0        Yarra  -37.8079   144.9934
# Abbotsford      134.0        Yarra  -37.8093   144.9944
# Abbotsford       94.0        Yarra  -37.7969   144.9969
# Abbotsford      120.0        Yarra  -37.8072   144.9941
#
#                       region_name  property_count
# suburb
# Abbotsford  Northern Metropolitan          4019.0
# Abbotsford  Northern Metropolitan          4019.0
# Abbotsford  Northern Metropolitan          4019.0
# Abbotsford  Northern Metropolitan          4019.0
# Abbotsford  Northern Metropolitan          4019.0

# %%
df['price'].max() - df['price'].min()
# Out:
# 8915000.0

# %% [markdown]
# Percentiles

# %%
df['price'].quantile(0.8)
# Out:
# 1440000.0

# %% [markdown]
# En este caso, el 80% de los valores en nuestro conjunto de datos tienen un valor menor o igual a 1 440 000.

# %%
print(f'Valor mínimo: {df["price"].min()}')
print(f'Percentil 10: {df["price"].quantile(0.1)}')
print(f'Percentil 25: {df["price"].quantile(0.25)}')
print(f'Percentil 50: {df["price"].median()}')
print(f'Percentil 75: {df["price"].quantile(0.75)}')
print(f'Percentil 90: {df["price"].quantile(0.9)}')
print(f'Valor máximo: {df["price"].max()}')
# Out:
# Valor mínimo: 85000.0
# Percentil 10: 470000.0
# Percentil 25: 640000.0
# Percentil 50: 895500.0
# Percentil 75: 1325000.0
# Percentil 90: 1850000.0
# Valor máximo: 9000000.0

# %% [markdown]
# Rango intercuartílico

# %% [markdown]
# Otra medida muy común es lo que llamamos el rango intercuartílico, que es la diferencia entre el percentil 75 y el percentil 25. Este número nos da una idea del rango que tienen los valores más cercanos al valor típico.

# %%
df['price'].quantile(0.75) - df['price'].quantile(0.25)
# Out:
# 685000.0
